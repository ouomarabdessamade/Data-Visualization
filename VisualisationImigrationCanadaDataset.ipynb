# %%
import pandas as pd
import numpy as np
import xlrd

# %%
df_can = pd.read_excel(r'C:\Users\Samad\Desktop\ProjetVisualisation\TPVisualisation\canada_immigrants.xlsx', engine='openpyxl', skipfooter=2)

# %%
#affichage de 5 dernier ligne , engine='openpyxl'
df_can.tail()
# Out:
#        Coverage                             Country  AREA  \
# 189  Foreigners  Venezuela (Bolivarian Republic of)   904
# 190  Foreigners                            Viet Nam   935
# 191  Foreigners                      Western Sahara   903
# 192  Foreigners                               Yemen   935
# 193  Foreigners                              Zambia   903
#
#                             AreaName  REG             RegName  1980  1981  \
# 189  Latin America and the Caribbean  931       South America   103   117
# 190                             Asia  920  South-Eastern Asia  1191  1829
# 191                           Africa  912     Northern Africa     0     0
# 192                             Asia  922        Western Asia     1     2
# 193                           Africa  910      Eastern Africa    11    17
#
#      1982  1983  ...  2004  2005  2006  2007  2008  2009  2010  2011  2012  \
# 189   174   124  ...  1224  1211  1192  1335  1239  1353   998  1452  1373
# ...

# %%
df_can.tail()
# Out:
#        Coverage                             Country  AREA  \
# 189  Foreigners  Venezuela (Bolivarian Republic of)   904
# 190  Foreigners                            Viet Nam   935
# 191  Foreigners                      Western Sahara   903
# 192  Foreigners                               Yemen   935
# 193  Foreigners                              Zambia   903
#
#                             AreaName  REG             RegName  1980  1981  \
# 189  Latin America and the Caribbean  931       South America   103   117
# 190                             Asia  920  South-Eastern Asia  1191  1829
# 191                           Africa  912     Northern Africa     0     0
# 192                             Asia  922        Western Asia     1     2
# 193                           Africa  910      Eastern Africa    11    17
#
#      1982  1983  ...  2004  2005  2006  2007  2008  2009  2010  2011  2012  \
# 189   174   124  ...  1224  1211  1192  1335  1239  1353   998  1452  1373
# ...

# %%
#change le nom de colonne
df_can.rename(columns ={'AreaName':'Continent', 'RegName':'Region'}, inplace= True)

# %%
#calcul de totale
df_can['Total']= df_can.sum(axis=1)
# Out:
# C:\Users\Samad\AppData\Local\Temp\ipykernel_2092\2988800338.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_can['Total']= df_can.sum(axis=1)

# %%
df_can.tail()
# Out:
#        Coverage                             Country  AREA  \
# 189  Foreigners  Venezuela (Bolivarian Republic of)   904
# 190  Foreigners                            Viet Nam   935
# 191  Foreigners                      Western Sahara   903
# 192  Foreigners                               Yemen   935
# 193  Foreigners                              Zambia   903
#
#                            Continent  REG              Region  1980  1981  \
# 189  Latin America and the Caribbean  931       South America   103   117
# 190                             Asia  920  South-Eastern Asia  1191  1829
# 191                           Africa  912     Northern Africa     0     0
# 192                             Asia  922        Western Asia     1     2
# 193                           Africa  910      Eastern Africa    11    17
#
#      1982  1983  ...  2005  2006  2007  2008  2009  2010  2011  2012  2013  \
# 189   174   124  ...  1211  1192  1335  1239  1353   998  1452  1373  1022
# ...

# %%
#des statistiques 
df_can.describe()
# Out:
#              AREA          REG         1980          1981          1982  \
# count  194.000000   194.000000    194.00000    194.000000    194.000000
# mean   912.814433  1250.762887    510.64433    569.324742    536.953608
# std     13.097743  1188.342406   1954.37904   2157.965743   1871.567530
# min    903.000000   905.000000      0.00000      0.000000      0.000000
# 25%    903.000000   914.000000      0.00000      0.000000      0.000000
# 50%    908.000000   922.000000     13.00000     10.000000     11.000000
# 75%    928.500000   925.750000    256.75000    295.750000    282.500000
# max    935.000000  5501.000000  22045.00000  24796.000000  20620.000000
#
#                1983          1984         1985         1986          1987  \
# count    194.000000    194.000000   194.000000   194.000000    194.000000
# mean     389.206186    378.273196   360.561856   443.324742    694.345361
# std     1207.195203   1201.089351  1081.840252  1228.411394   2114.184604
# ...

# %%
df_can.Country
# Out:
# 0                             Afghanistan
# 1                                 Albania
# 2                                 Algeria
# 3                          American Samoa
# 4                                 Andorra
#                       ...
# 189    Venezuela (Bolivarian Republic of)
# 190                              Viet Nam
# 191                        Western Sahara
# 192                                 Yemen
# 193                                Zambia
# Name: Country, Length: 194, dtype: object

# %%
df_can2 = df_can[['Country',1980, 1981, 1982, 1983]]

# %%
df_can2.tail()
# Out:
#                                 Country  1980  1981  1982  1983
# 189  Venezuela (Bolivarian Republic of)   103   117   174   124
# 190                            Viet Nam  1191  1829  2162  3404
# 191                      Western Sahara     0     0     0     0
# 192                               Yemen     1     2     1     6
# 193                              Zambia    11    17    11     7

# %%
df_can.set_index('Country', inplace=True)

# %%
df_can.tail()
# Out:
#                                       Coverage  AREA  \
# Country
# Venezuela (Bolivarian Republic of)  Foreigners   904
# Viet Nam                            Foreigners   935
# Western Sahara                      Foreigners   903
# Yemen                               Foreigners   935
# Zambia                              Foreigners   903
#
#                                                           Continent  REG  \
# Country
# Venezuela (Bolivarian Republic of)  Latin America and the Caribbean  931
# Viet Nam                                                       Asia  920
# Western Sahara                                               Africa  912
# Yemen                                                          Asia  922
# Zambia                                                       Africa  910
#
#                                                 Region  1980  1981  1982  \
# Country
# Venezuela (Bolivarian Republic of)       South America   103   117   174
# ...

# %%
df_can.loc['Morocco']
# Out:
# Coverage          Foreigners
# AREA                     903
# Continent             Africa
# REG                      912
# Region       Northern Africa
# 1980                     325
# 1981                     471
# 1982                     447
# 1983                     335
# 1984                     248
# 1985                     328
# 1986                     388
# 1987                     505
# 1988                     685
# 1989                    1060
# 1990                    1313
# 1991                    1390
# 1992                    1055
# 1993                    1042
# 1994                     660
# 1995                    1069
# 1996                     939
# 1997                    1095
# 1998                    1262
# 1999                    1870
# 2000                    2664
# 2001                    4067
# 2002                    4174
# 2003                    3369
# 2004                    3686
# 2005                    2939
# 2006                    3322
# ...

# %%
df_can[df_can.index =='Japan']
# Out:
#            Coverage  AREA Continent  REG        Region  1980  1981  1982  \
# Country
# Japan    Foreigners   935      Asia  906  Eastern Asia   701   756   598
#
#          1983  1984  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# Country              ...
# Japan     309   246  ...  1067  1212  1250  1284  1194  1168  1265  1214
#
#          2013  Total
# Country
# Japan     982  29548
#
# [1 rows x 40 columns]

# %%
df_can[df_can.index =='Japan'].T
# Out:
# Country           Japan
# Coverage     Foreigners
# AREA                935
# Continent          Asia
# REG                 906
# Region     Eastern Asia
# 1980                701
# 1981                756
# 1982                598
# 1983                309
# 1984                246
# 1985                198
# 1986                248
# 1987                422
# 1988                324
# 1989                494
# 1990                379
# 1991                506
# 1992                605
# 1993                907
# 1994                956
# 1995                826
# 1996                994
# 1997                924
# 1998                897
# 1999               1083
# 2000               1010
# 2001               1092
# 2002                806
# 2003                817
# 2004                973
# 2005               1067
# 2006               1212
# 2007               1250
# 2008               1284
# 2009               1194
# 2010               1168
# 2011               1265
# ...

# %%
df_can[df_can.index =='Japan'].T.squeeze()
# Out:
# Coverage       Foreigners
# AREA                  935
# Continent            Asia
# REG                   906
# Region       Eastern Asia
# 1980                  701
# 1981                  756
# 1982                  598
# 1983                  309
# 1984                  246
# 1985                  198
# 1986                  248
# 1987                  422
# 1988                  324
# 1989                  494
# 1990                  379
# 1991                  506
# 1992                  605
# 1993                  907
# 1994                  956
# 1995                  826
# 1996                  994
# 1997                  924
# 1998                  897
# 1999                 1083
# 2000                 1010
# 2001                 1092
# 2002                  806
# 2003                  817
# 2004                  973
# 2005                 1067
# 2006                 1212
# 2007                 1250
# 2008                 1284
# 2009                 1194
# ...

# %%
df_can.loc[['Japan','Albania'], [1980, 2013]]
# Out:
#          1980  2013
# Country
# Japan     701   982
# Albania     1   603

# %%
df_can.loc[['Morocco','Algeria','Tunisia'], [2008, 2009,2010, 2011, 2012, 2013]]
# Out:
#          2008  2009  2010  2011  2012  2013
# Country
# Morocco  4226  5532  6242  4399  3878  3261
# Algeria  4005  5393  4752  4325  3774  4331
# Tunisia   950  1195  1299  1442  1503  1627

# %%
# finally, let's create a list of years from 1980 - 2013 using list(map(str, range(1980, 2014)))

years = list(map(str, range(1980, 2014)))

years
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
df_can_Asia = df_can[df_can['Continent'] == 'Asia']

# %%
df_can_Asia
# Out:
#                                                   Coverage  AREA Continent  \
# Country
# Afghanistan                                     Foreigners   935      Asia
# Armenia                                         Foreigners   935      Asia
# Azerbaijan                                      Foreigners   935      Asia
# Bahrain                                         Foreigners   935      Asia
# Bangladesh                                      Foreigners   935      Asia
# Bhutan                                          Foreigners   935      Asia
# Brunei Darussalam                               Foreigners   935      Asia
# Cambodia                                        Foreigners   935      Asia
# China                                           Foreigners   935      Asia
# China, Hong Kong Special Administrative Region  Foreigners   935      Asia
# China, Macao Special Administrative Region      Foreigners   935      Asia
# ...

# %%
df_can_Africa = df_can[df_can['Continent'] == 'Africa']

# %%
df_can_Africa
# Out:
#                                     Coverage  AREA Continent  REG  \
# Country
# Algeria                           Foreigners   903    Africa  912
# Angola                            Foreigners   903    Africa  911
# Benin                             Foreigners   903    Africa  914
# Botswana                          Foreigners   903    Africa  913
# Burkina Faso                      Foreigners   903    Africa  914
# Burundi                           Foreigners   903    Africa  910
# Cabo Verde                        Foreigners   903    Africa  914
# Cameroon                          Foreigners   903    Africa  911
# Central African Republic          Foreigners   903    Africa  911
# Chad                              Foreigners   903    Africa  911
# Comoros                           Foreigners   903    Africa  910
# Congo                             Foreigners   903    Africa  911
# Côte d'Ivoire                     Foreigners   903    Africa  914
# ...

# %%
print(df_can['Continent'] == 'Africa')
# Out:
# Country
# Afghanistan                           False
# Albania                               False
# Algeria                                True
# American Samoa                        False
# Andorra                               False
#                                       ...
# Venezuela (Bolivarian Republic of)    False
# Viet Nam                              False
# Western Sahara                         True
# Yemen                                 False
# Zambia                                 True
# Name: Continent, Length: 194, dtype: bool

# %%
df_can_Asia_Africa = df_can[(df_can['Continent'] == 'Asia') & (df_can['Continent'] == 'Africa')]

# %%
df_can_Asia_Africa
# Out:
# Empty DataFrame
# Columns: [Coverage, AREA, Continent, REG, Region, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, Total]
# Index: []
#
# [0 rows x 40 columns]

# %% [markdown]
# # Visualizing Data using Matplotlib<a id="4"></a>

# %%
#% matplotlib inline
import matplotlib as mlp
import matplotlib.pyplot as plt

# %matplotlib inline 
mpl.style.use('ggplot')

# %%
list_columns = []
for x in df_can.columns.values :
    list_columns.append(str(x))
df_can.columns = list_columns

# %%
#visualiser une ligne 
df_Haiti = df_can.loc['Haiti', years]

# %%
df_Haiti.plot(kind='line')
plt.show()

# %%
df_Haiti.index = df_Haiti.index.map(int)
df_Haiti.plot()
plt.text(2000, 6000, '2010 Earthquake' )
plt.title('Imigration from Haiti')
plt.xlabel('years')
plt.ylabel('Number of Immigrations')
plt.show()

# %%
df__fr_Mexic = df_can.loc[['France', 'Mexico'], years]
df__fr_Mexic = df__fr_Mexic.transpose()
df__fr_Mexic.plot(kind='line')
plt.title('Imigration from France and Mexico')
plt.xlabel('years')
plt.ylabel('Number of Immigrations')
plt.show()

# %%
df__Maroc_Alger = df_can.loc[['Morocco', 'Algeria'], years]
df__Maroc_Alger = df__Maroc_Alger.transpose()
df__Maroc_Alger.plot(kind='line')
plt.title('Imigration from Morocco and Algeria')
plt.xlabel('years')
plt.ylabel('Number of Immigrations')
plt.show()

# %%
df__fr_Mexic_America = df_can.loc[['France', 'Mexico', 'United States of America'], years]
df__fr_Mexic_America = df__fr_Mexic_America.transpose()
df__fr_Mexic_America.plot(kind='line')
plt.title('Imigration from France and Mexico and America')
plt.xlabel('years')
plt.ylabel('Number of Immigrations')
plt.show()

# %%
#les 5 majour pays
df_top5 = df_can.sort_values(by='Total', ascending= False, axis=0)
df_top5 = df_top5.head()
df_top5 = df_top5[years].transpose()
df_top5.plot(kind='line')
df_top5.plot(figsize=(20, 10))
plt.title('Imigration from the 5 Country')
plt.xlabel('years')
plt.ylabel('Number of Immigrations')
plt.show()

# %% [markdown]
# # Area Plots<a id="6"></a>

# %%
df_can.sort_values(['Total'], ascending=False)
df_can.head()
# Out:
#                   Coverage  AREA Continent   REG           Region  1980  1981  \
# Country
# Afghanistan     Foreigners   935      Asia  5501    Southern Asia    16    39
# Albania         Foreigners   908    Europe   925  Southern Europe     1     0
# Algeria         Foreigners   903    Africa   912  Northern Africa    80    67
# American Samoa  Foreigners   909   Oceania   957        Polynesia     0     1
# Andorra         Foreigners   908    Europe   925  Southern Europe     0     0
#
#                 1982  1983  1984  ...  2005  2006  2007  2008  2009  2010  \
# Country                           ...
# Afghanistan       39    47    71  ...  3436  3009  2652  2111  1746  1758
# Albania            0     0     0  ...  1223   856   702   560   716   561
# Algeria           71    69    63  ...  3626  4807  3623  4005  5393  4752
# American Samoa     0     0     0  ...     0     1     0     0     0     0
# Andorra            0     0     0  ...     0     1     1     0     0     0
#
# ...

# %%
print ('data dimensions:', df_can.shape)
# Out:
# data dimensions: (194, 40)

# %%
df_top5 = df_can.head()

# %%
df_top5= df_top5[years].transpose()
df_top5
# Out:
# Country  Afghanistan  Albania  Algeria  American Samoa  Andorra
# 1980              16        1       80               0        0
# 1981              39        0       67               1        0
# 1982              39        0       71               0        0
# 1983              47        0       69               0        0
# 1984              71        0       63               0        0
# 1985             340        0       44               0        0
# 1986             496        1       69               0        2
# 1987             741        2      132               1        0
# 1988             828        2      242               0        0
# 1989            1076        3      434               1        0
# 1990            1028        3      491               2        3
# 1991            1378       21      872               0        0
# 1992            1170       56      795               0        1
# 1993             713       96      717               0        0
# ...

# %%
df_top5.index = df_top5.index.map(int)
df_top5.plot(kind='area', stacked=False, figsize=(20,10))
plt.title('Imigration Trend of top 5 countries')
plt.xlabel('years')
plt.ylabel('Number of Immigrants')
plt.show()

# %%
df_top5.index = df_top5.index.map(int)
df_top5.plot(kind='area', stacked=False, figsize=(20,10), alpha=0.25)
plt.title('Imigration Trend of top 5 countries')
plt.xlabel('years')
plt.ylabel('Number of Immigrants')
plt.show()

# %%
ax = df_top5.plot(kind='area', stacked=False, figsize=(20,10), alpha=0.25)
ax.set_title('Imigration Trend of top 5 countries')
ax.set_xlabel('years')
ax.set_ylabel('Number of Immigrants')
# Out:
# Text(0, 0.5, 'Number of Immigrants')

# %%
df_least5 = df_can.tail()
df_least5 = df_least5[years].T
df_least5.index = df_least5.index.map(int)
df_least5.plot(kind='area', stacked=False, figsize=(20,10))
plt.title('immigration Trend of 5 countries of laste contribution of immigration')
plt.xlabel('years')
plt.ylabel('Number of Immigrants')
# Out:
# Text(0, 0.5, 'Number of Immigrants')

# %% [markdown]
# # Histograms<a id="8"></a>
#
# A histogram is a way of representing the *frequency* distribution of numeric dataset. The way it works is it partitions the x-axis into *bins*, assigns each data point in our dataset to a bin, and then counts the number of data points that have been assigned to each bin. So the y-axis is the frequency or the number of data points in each bin. Note that we can change the bin size and usually one needs to tweak it so that the distribution is displayed nicely.

# %%
df_can['2013'].head()
# Out:
# Country
# Afghanistan       2004
# Albania            603
# Algeria           4331
# American Samoa       0
# Andorra              1
# Name: 2013, dtype: int64

# %%
count, bin_adges = np.histogram(df_can['2013'])
df_can['2013'].plot(kind='hist', figsize=(15, 7))
plt.xlabel('number of imigrate')
plt.ylabel('number of countries')
plt.title('Histogram of immigray')
plt.show()

# %%
bin_adges
# Out:
# array([    0. ,  3412.9,  6825.8, 10238.7, 13651.6, 17064.5, 20477.4,
#        23890.3, 27303.2, 30716.1, 34129. ])

# %%
count, bn_edge = np.histogram(df_can['2013'])
df_can['2013'].plot(kind='hist', figsize=(15, 7), xticks=bin_adges)
plt.xlabel('number of imigrate')
plt.ylabel('number of countries')
plt.title('Histogram of immigray')
plt.show()

# %%
df_can.loc[['Denmark', 'Norway', 'Sweden'], years]
# Out:
#          1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  ...  \
# Country                                                              ...
# Denmark   272   293   299   106    93    73    93   109   129   129  ...
# Norway    116    77   106    51    31    54    56    80    73    76  ...
# Sweden    281   308   222   176   128   158   187   198   171   182  ...
#
#          2004  2005  2006  2007  2008  2009  2010  2011  2012  2013
# Country
# Denmark    89    62   101    97   108    81    92    93    94    81
# Norway     73    57    53    73    66    75    46    49    53    59
# Sweden    129   205   139   193   165   167   159   134   140   140
#
# [3 rows x 34 columns]

# %%
def_c_scondinave = df_can.loc[['Denmark', 'Norway', 'Sweden'], years].transpose()
def_c_scondinave.plot(kind='hist', figsize=(15, 7))
plt.xlabel('number of Immigrants')
plt.ylabel('number of years')
plt.title('Histogram of immigration from Denmark, Norway and Sweden from 1989-2013')
# Out:
# Text(0.5, 1.0, 'Histogram of immigration from Denmark, Norway and Sweden from 1989-2013')

# %%
def_c_scondinave = df_can.loc[['Denmark', 'Norway', 'Sweden'], years].transpose()
counts, bin_edges = np.histogram(def_c_scondinave)
def_c_scondinave.plot(kind='hist', figsize=(15, 7), alpha=0.5, xticks = bin_edges, bins=15, color=['coral', 'darkslateblue', 'mediumseagreen'] )
plt.xlabel('number of Immigrants')
plt.ylabel('number of years')
plt.title('Histogram of immigration from Denmark, Norway and Sweden from 1989-2013')
# Out:
# Text(0.5, 1.0, 'Histogram of immigration from Denmark, Norway and Sweden from 1989-2013')

# %%
counts, bin_edges = np.histogram(def_c_scondinave, 20)
def_c_scondinave.plot(kind='hist', figsize=(15, 7), alpha=0.5, xticks=bin_edges, bins=20, color=['coral', 'darkslateblue', 'mediumseagreen'] )
plt.xlabel('number of Immigrants')
plt.ylabel('number of years')
plt.title('Histogram of immigration from Denmark, Norway and Sweden from 1989-2013')
# Out:
# Text(0.5, 1.0, 'Histogram of immigration from Denmark, Norway and Sweden from 1989-2013')

# %%
de_can_icland = df_can.loc[['Iceland'], years].T #cell 1
de_can_icland
# Out:
# Country  Iceland
# 1980          17
# 1981          33
# 1982          10
# 1983           9
# 1984          13
# 1985           6
# 1986          11
# 1987          11
# 1988           7
# 1989           3
# 1990           2
# 1991          11
# 1992          17
# 1993          15
# 1994          11
# 1995           9
# 1996          14
# 1997          11
# 1998          20
# 1999          17
# 2000           9
# 2001          26
# 2002          11
# 2003          17
# 2004          23
# 2005          10
# 2006           2
# 2007          15
# 2008          13
# 2009          15
# 2010          30
# 2011          38
# 2012          42
# 2013          72

# %%
de_can_icland.plot(kind='bar', figsize=(20, 10))
plt.title('Icelandic immigrants to Canada from 1980 to 2013')
plt.xlabel('Number of immigrants')
plt.ylabel('years')
plt.show()

# %%
#ajoute de la rotation et une notation sur le graphe
de_can_icland.plot(kind='bar', figsize=(20, 10), rot=90)
plt.annotate('', 
             xy=(32, 70),
             xytext=(28, 20), 
             xycoords='data', 
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='red', lw=3)
            )
plt.annotate('2018 - 2011 Financial Crisis', xy=(28, 30), rotation=69, va='bottom', ha='left')
plt.title('Icelandic immigrants to Canada from 1980 to 2013')
plt.xlabel('Number of immigrants')
plt.ylabel('years')
plt.show()

# %%
df_top15 = df_can.sort_values(['Total'], ascending=True)
df_top15 = df_top15['Total'].tail(15)
df_top15
# Out:
# Country
# Romania                                                  95416
# Viet Nam                                                 99001
# Jamaica                                                 108250
# France                                                  110925
# Lebanon                                                 117216
# Poland                                                  141072
# Republic of Korea                                       144422
# Sri Lanka                                               154794
# Iran (Islamic Republic of)                              182359
# United States of America                                242932
# Pakistan                                                248036
# Philippines                                             513246
# United Kingdom of Great Britain and Northern Ireland    553332
# China                                                   661803
# India                                                   698340
# ...

# %%
df_top15.plot(kind ='barh', figsize=(20, 10), color='steelblue')
plt.title('Top 15 Conuntries Contributing to the Immigration to Canada between 1980 - 2013')
plt.xlabel('Number of Immigrants')
for index, value in enumerate(df_top15):
    label  = format(int(value),',')
    plt.annotate(label, xy=(value - 47000, index - 0.10), color = 'white')

# %% [markdown]
# # Pie Charts <a id="6"></a>
#
# A `pie chart` is a circualr graphic that displays numeric proportions by dividing a circle (or pie) into proportional slices. You are most likely already familiar with pie charts as it is widely used in business and media. We can create pie charts in Matplotlib by passing in the `kind=pie` keyword.
#
# Let's use a pie chart to explore the proportion (percentage) of new immigrants grouped by continents for the entire time period from 1980 to 2013.

# %%
# %matplotlib inline
import matplotlib as mpl 
import matplotlib.pyplot as plt

# %%
mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# Matplotlib version:  3.5.1

# %%
df_continent = df_can.groupby('Continent', axis=0).sum()
df_continent
# Out:
#                                   AREA     REG   1980   1981   1982   1983  \
# Continent
# Africa                           47859   48332   3879   4249   3717   2627
# Asia                             45815  109147  31025  34314  30214  24696
# Europe                           39044   39754  39760  44802  42720  24638
# Latin America and the Caribbean  29832   30395  13081  15215  16769  15427
# Northern America                  1810    1810   9378  10030   9074   7100
# Oceania                          12726   13210   1942   1839   1675   1018
#
#                                   1984   1985   1986   1987  ...    2005  \
# Continent                                                    ...
# Africa                            2607   2621   3739   7426  ...   26908
# Asia                             27274  23850  28739  43203  ...  159253
# Europe                           22287  20844  24370  46698  ...   35955
# ...

# %%
df_continent['Total'].plot(kind='pie', figsize=(7,9), autopct='%1.1f%%', startangle=90, shadow=True)
plt.title('Immigration to Canada by Continent [1980 - 2013]')
plt.xlabel('equa')
plt.show()

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explod_list = [0.1, 0, 0, 0, 0.1, 0.1]
df_continent['Total'].plot(kind='pie', figsize=(15,15), autopct='%1.1f%%', startangle=90, colors=colors_list, explode=explod_list,  shadow=True)
plt.title('Immigration to Canada by Continent [1980 - 2013]')
plt.xlabel('equa')
plt.legend(labels=df_continent.index, loc='upper left')
plt.show()

# %% [markdown]
# # Box Plots <a id="8"></a>
#
# A `box plot` is a way of statistically representing the *distribution* of the data through five main dimensions:
#
# - **Minimun:** Smallest number in the dataset.
# - **First quartile:** Middle number between the `minimum` and the `median`.
# - **Second quartile (Median):** Middle number of the (sorted) dataset.
# - **Third quartile:** Middle number between `median` and `maximum`.
# - **Maximum:** Highest number in the dataset.

# %%
df_Japan = df_can.loc[['Japan'], years].T
df_Japan.describe()
df_Japan.plot(kind='box', figsize=(8, 6))
plt.title('Box plot of Japanese Immigrants from 1980 - 2013')
plt.ylabel('Number of Immigrants')
plt.show()

# %%
df_China_india = df_can.loc[['China', 'India'], years].T
df_China_india.describe()
# Out:
# Country         China         India
# count       34.000000     34.000000
# mean     19410.647059  20350.117647
# std      13568.230790  10007.342579
# min       1527.000000   4211.000000
# 25%       5512.750000  10637.750000
# 50%      19945.000000  20235.000000
# 75%      31568.500000  28699.500000
# max      42584.000000  36210.000000

# %%
df_China_india.head()
# Out:
# Country  China  India
# 1980      5123   8880
# 1981      6682   8670
# 1982      3308   8147
# 1983      1863   7338
# 1984      1527   5704

# %%
df_China_india.plot(kind='box', figsize=(10, 8))
plt.title('Box plot of Immigrants from China and india (1980 - 2013)')
plt.ylabel('Number of Immigrants')
plt.show()

# %%
fig = plt.figure() # create figure
ax1 = fig.add_subplot(1, 2, 1) # create subplots
df_Japan = df_can.loc[['Japan'], years].T
df_Japan.describe()
df_Japan.plot(kind='box', figsize=(8, 6), ax=ax1)
ax1.set_title('Box plot of Japanese Immigrants from 1980 - 2013')
ax1.set_ylabel('Number of Immigrants')


ax2 = fig.add_subplot(1, 2, 2)
df_Japan.plot(kind='box', figsize=(20, 10), ax=ax2)
ax2.set_title('Box plot of Japanese Immigrants from 1980 - 2013')
ax2.set_ylabel('Number of Immigrants')
plt.show()

# %%
df_top15 = df_can.sort_values(['Total'], ascending=False, axis=0).head(15)
df_top15
# Out:
#                                                       Coverage  AREA  \
# Country
# India                                               Foreigners   935
# China                                               Foreigners   935
# United Kingdom of Great Britain and Northern Ir...  Foreigners   908
# Philippines                                         Foreigners   935
# Pakistan                                            Foreigners   935
# United States of America                            Foreigners   905
# Iran (Islamic Republic of)                          Foreigners   935
# Sri Lanka                                           Foreigners   935
# Republic of Korea                                   Foreigners   935
# Poland                                              Foreigners   908
# Lebanon                                             Foreigners   935
# France                                              Foreigners   908
# ...

# %%
# create a list of all years in decades 80's, 90's, and 00's
years_80 = list(map(str, range(1980, 1990))) 
years_90 = list(map(str, range(1990, 2000))) 
years_00 = list(map(str, range(2000, 2010)))

# %%
df_80 = df_top15.loc[:, years_80].sum(axis=1) 
df_90 = df_top15.loc[:, years_90].sum(axis=1) 
df_00 = df_top15.loc[:, years_00].sum(axis=1)

# %%
new_df = pd.DataFrame({'1980': df_80, '1990': df_90, '2000':df_00})

# %%
new_df.plot(kind='box', figsize=(20, 10))
plt.title('Immigration from top 15 countries for decades 80s, 90s and 2000s')
plt.ylabel('Number of Immigrants')
plt.show()

# %% [markdown]
# #    Folium library

# %%
import folium as fl

# %%
#define the world map
world_map = fl.Map()

#display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#define the world mp centered around
#canada with 
world_map = fl.Map(location=[56.130, -106.35],
                  zoom_start=4)

# %%
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
world_map = fl.Map(
                  location=[56.130, -106.35],
                  zoom_start=4,
                  tiles='Stamen Toner' )
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#generate ma of canada 
world_map = fl.Map(
                  location=[56.130, -106.35],
                  zoom_start=4,
                  )
##add a red marker to ontario

#create a feature group
ontario = fl.map.FeatureGroup()

#style the feature group
ontario.add_child(
                   fl.features.CircleMarker(
                   [51.25, -85.30], radius= 5,     
                   color='red', fill_color='red'), 
                  )

#add the feature group to the map
world_map.add_child(ontario)

#label the marker
fl.Marker([51.25, -85.30], popup='ontario').add_to(world_map)
#display map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import os
import pandas as pd

state_geo = os.path.join('data','us-states.json')
#print(state_geo)

state_unemployment=os.path.join('data','US_Unemployment_Oct2012.csv')
#print(state_unemployment)

state_data = pd.read_csv(state_unemployment)

 
m = fl.Map(location=[48,-102],zoom_start=3)
print(m)


fl.Choropleth(geo_data=state_geo,
             data = state_data,
             columns=['State', 'Unemployment'],
             key_on = 'feature.id',
             fill_color ='Reds',
             fill_opacity=0.7,
             line_opacity=0.5,
             legend_name='Unemployment Rate (%)'
             ).add_to(m)
m
# Out:
# ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
